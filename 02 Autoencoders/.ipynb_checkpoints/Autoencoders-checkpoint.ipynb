# %%
import keras

% pylab inline
# Out:
# /home/soph/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Populating the interactive namespace from numpy and matplotlib

# %%
# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = keras.layers.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = keras.layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = keras.layers.Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = keras.models.Model(input_img, decoded)

# %%
# this model maps an input to its encoded representation
encoder = keras.models.Model(input_img, encoded)

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = keras.layers.Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = keras.models.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(
        factor=.5, patience=1, verbose=1, min_lr=1e-6),
    keras.callbacks.EarlyStopping(patience=5, verbose=1, min_delta=0.0001)
]

# %%
autoencoder.fit(x_train, x_train, batch_size=256,
                epochs=50,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=callbacks
               )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2241 - val_loss: 0.1560
# Epoch 2/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.1385 - val_loss: 0.1247
# Epoch 3/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.1176 - val_loss: 0.1102
# Epoch 4/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.1077 - val_loss: 0.1031
# Epoch 5/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.1024 - val_loss: 0.0993
# Epoch 6/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0992 - val_loss: 0.0970
# Epoch 7/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0976 - val_loss: 0.0966
# Epoch 8/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0965 - val_loss: 0.0947
# Epoch 9/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0954 - val_loss: 0.0937
# Epoch 10/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0949 - val_loss: 0.0953
# Epoch 11/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0944 - val_loss: 0.0937
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 12/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 13/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0936 - val_loss: 0.0924
# Epoch 14/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0935 - val_loss: 0.0923
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 16/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 17/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0932 - val_loss: 0.0919
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 18/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 19/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 20/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0930 - val_loss: 0.0918
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 21/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0930 - val_loss: 0.0917
# Epoch 22/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0930 - val_loss: 0.0917
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 23/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 24/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 25/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 26/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 27/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 28/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 29/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 30/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 31/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 32/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 33/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 34/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 35/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 36/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 37/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 38/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 39/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 40/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 41/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 42/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 43/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 44/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 45/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 46/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 47/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 48/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 49/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.0929 - val_loss: 0.0917
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 50/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0929 - val_loss: 0.0917

# %%
input_img = keras.layers.Input(shape=(784,))
encoded = keras.layers.Dense(128, activation='relu')(input_img)
encoded = keras.layers.Dense(64, activation='relu')(encoded)
encoded = keras.layers.Dense(32, activation='relu')(encoded)

decoded = keras.layers.Dense(64, activation='relu')(encoded)
decoded = keras.layers.Dense(128, activation='relu')(decoded)
decoded = keras.layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train, x_train, batch_size=256,
                epochs=100,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=callbacks
               )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2083 - val_loss: 0.1605
# Epoch 2/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1497 - val_loss: 0.1508
# Epoch 3/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1351 - val_loss: 0.1266
# Epoch 4/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1263 - val_loss: 0.1219
# Epoch 5/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.1200 - val_loss: 0.1126
# Epoch 6/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.1152 - val_loss: 0.1120
# Epoch 7/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.1117 - val_loss: 0.1110
# Epoch 8/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.1088 - val_loss: 0.1082
# Epoch 9/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.1065 - val_loss: 0.1058
# Epoch 10/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1044 - val_loss: 0.1063
# Epoch 11/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1026 - val_loss: 0.1000
# Epoch 12/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1012 - val_loss: 0.0981
# Epoch 13/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0999 - val_loss: 0.0981
# Epoch 14/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0986 - val_loss: 0.1003
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 15/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0928 - val_loss: 0.0919
# Epoch 16/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0921 - val_loss: 0.0918
# Epoch 17/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0919 - val_loss: 0.0911
# Epoch 18/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0917 - val_loss: 0.0907
# Epoch 19/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0913 - val_loss: 0.0906
# Epoch 20/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0909 - val_loss: 0.0908
# Epoch 21/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0903 - val_loss: 0.0900
# Epoch 22/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0898 - val_loss: 0.0894
# Epoch 23/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0893 - val_loss: 0.0892
# Epoch 24/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0888 - val_loss: 0.0882
# Epoch 25/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0883 - val_loss: 0.0875
# Epoch 26/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0878 - val_loss: 0.0875
# Epoch 27/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0874 - val_loss: 0.0871
# Epoch 28/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0869 - val_loss: 0.0869
# Epoch 29/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0865 - val_loss: 0.0864
# Epoch 30/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0861 - val_loss: 0.0863
# Epoch 31/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0857 - val_loss: 0.0853
# Epoch 32/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0853 - val_loss: 0.0857
# Epoch 33/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0850 - val_loss: 0.0847
# Epoch 34/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0847 - val_loss: 0.0841
# Epoch 35/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0843 - val_loss: 0.0845
# Epoch 36/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0841 - val_loss: 0.0836
# Epoch 37/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0837 - val_loss: 0.0836
# Epoch 38/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0834 - val_loss: 0.0830
# Epoch 39/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0831 - val_loss: 0.0843
# Epoch 40/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0829 - val_loss: 0.0826
# Epoch 41/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0827 - val_loss: 0.0821
# Epoch 42/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0824 - val_loss: 0.0821
# Epoch 43/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0822 - val_loss: 0.0828
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 44/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0810 - val_loss: 0.0808
# Epoch 45/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0808 - val_loss: 0.0807
# Epoch 46/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0807 - val_loss: 0.0807
# Epoch 47/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0807 - val_loss: 0.0806
# Epoch 48/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0806 - val_loss: 0.0805
# Epoch 49/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0805 - val_loss: 0.0806
# Epoch 50/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0804 - val_loss: 0.0805
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 51/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0801 - val_loss: 0.0800
# Epoch 52/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0800 - val_loss: 0.0799
# Epoch 53/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0800 - val_loss: 0.0799
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 54/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0798 - val_loss: 0.0797
# Epoch 55/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0798 - val_loss: 0.0797
# Epoch 56/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0798 - val_loss: 0.0797
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0797 - val_loss: 0.0796
# Epoch 58/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0797 - val_loss: 0.0796
# Epoch 59/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0796 - val_loss: 0.0796
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 60/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0796 - val_loss: 0.0795
# Epoch 61/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0796 - val_loss: 0.0795
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 62/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0796 - val_loss: 0.0795
# Epoch 63/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0796 - val_loss: 0.0795
# Epoch 64/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0796 - val_loss: 0.0795
# Epoch 65/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 66/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 67/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 68/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 69/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 70/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 71/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 72/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 73/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 74/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 75/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 76/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 77/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 78/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 79/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 80/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 81/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 82/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 83/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 84/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 85/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 86/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 87/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 88/100
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 89/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 90/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 91/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 92/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 93/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 94/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 95/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 96/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 97/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 98/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 99/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0795 - val_loss: 0.0795
# Epoch 100/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.0795 - val_loss: 0.0795

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

fig, axes = plt.subplots(nrows=2, ncols=n, figsize=(20,4))
for i in range(n):
    # display original
    ax = axes[0,i]
    ax.imshow(x_test[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = axes[1,i]
    ax.imshow(decoded_imgs[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.layers.Input(
    shape=(28, 28,
           1))  # adapt this if using `channels_first` image data format

x = keras.layers.Conv2D(
    16, (3, 3), activation='elu', padding='same')(input_img)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(32, (3, 3), activation='elu', padding='same')(x)
encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (1, 1, 32) i.e. 128-dimensional

x = keras.layers.Conv2DTranspose(
    32, (3, 3), strides=(2, 2), activation="elu", padding='valid')(encoded)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='valid')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

decoded = keras.layers.Conv2D(
    1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.models.Model(input_img, decoded)

autoencoder.summary()

autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 16)        2320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 16)          2320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 16)          2320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 16)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 32)          4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 32)          0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 3, 3, 32)          9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 16)          4624
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 7, 7, 16)          2320
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 7, 16)          2320
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 14, 14, 16)        2320
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 16)        2320
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 28, 28, 16)        2320
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 39,697
# Trainable params: 39,697
# Non-trainable params: 0
# _________________________________________________________________

# %%
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))  # adapt this if using `channels_first` image data format
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))  # adapt this if using `channels_first` image data format

# %%
autoencoder.fit(x_train, x_train, batch_size=256,
                epochs=100,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=callbacks
               )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.2418 - val_loss: 0.1770
# Epoch 2/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1530 - val_loss: 0.1464
# Epoch 3/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1314 - val_loss: 0.1283
# Epoch 4/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1208 - val_loss: 0.1155
# Epoch 5/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.1136 - val_loss: 0.1116
# Epoch 6/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1082 - val_loss: 0.1073
# Epoch 7/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1047 - val_loss: 0.1013
# Epoch 8/100
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.1016 - val_loss: 0.0992
# Epoch 9/100
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0990 - val_loss: 0.0988
# Epoch 10/100
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0971 - val_loss: 0.0975
# Epoch 11/100
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0953 - val_loss: 0.0950
# Epoch 12/100
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0937 - val_loss: 0.0907
# Epoch 13/100
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0924 - val_loss: 0.0881
# Epoch 14/100
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0910 - val_loss: 0.0922
# Epoch 15/100
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0899 - val_loss: 0.0889
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 16/100
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0845 - val_loss: 0.0834
# Epoch 17/100
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0840 - val_loss: 0.0829
# Epoch 18/100
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0839 - val_loss: 0.0834
# Epoch 19/100
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0838 - val_loss: 0.0828
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0819 - val_loss: 0.0811
# Epoch 21/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0815 - val_loss: 0.0808
# Epoch 22/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0812 - val_loss: 0.0805
# Epoch 23/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0811 - val_loss: 0.0814
# Epoch 24/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0809 - val_loss: 0.0798
# Epoch 25/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0806 - val_loss: 0.0806
# Epoch 26/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0803 - val_loss: 0.0797
# Epoch 27/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0801 - val_loss: 0.0796
# Epoch 28/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0798 - val_loss: 0.0789
# Epoch 29/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0796 - val_loss: 0.0788
# Epoch 30/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0793 - val_loss: 0.0786
# Epoch 31/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0791 - val_loss: 0.0792
# Epoch 32/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0789 - val_loss: 0.0786
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 33/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0782 - val_loss: 0.0776
# Epoch 34/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0781 - val_loss: 0.0775
# Epoch 35/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0780 - val_loss: 0.0775
# Epoch 36/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0779 - val_loss: 0.0774
# Epoch 37/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0778 - val_loss: 0.0774
# Epoch 38/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0777 - val_loss: 0.0772
# Epoch 39/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0776 - val_loss: 0.0771
# Epoch 40/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0775 - val_loss: 0.0771
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 41/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0772 - val_loss: 0.0767
# Epoch 42/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0772 - val_loss: 0.0766
# Epoch 43/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0771 - val_loss: 0.0766
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 44/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0770 - val_loss: 0.0765
# Epoch 45/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0770 - val_loss: 0.0765
# Epoch 46/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0770 - val_loss: 0.0764
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 47/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0769 - val_loss: 0.0764
# Epoch 48/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0769 - val_loss: 0.0764
# Epoch 49/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0769 - val_loss: 0.0763
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 50/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 51/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 52/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 53/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 54/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 55/100
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 56/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 57/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 58/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 59/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 60/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 61/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 62/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 63/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 64/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 65/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 66/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 67/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 68/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 69/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 70/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 71/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 72/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 73/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 74/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 75/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 76/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 77/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 78/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 79/100
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 80/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 81/100
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0768 - val_loss: 0.0763
# Epoch 82/100
# 13312/60000 [=====>........................] - ETA: 4s - loss: 0.0768
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# <ipython-input-19-e899f2253ebe> in <module>()
#       3                 shuffle=True,
#       4                 validation_data=(x_test, x_test),
# ----> 5                 callbacks=callbacks
#       6                )
#
# ~/miniconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/miniconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/miniconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

fig, axes = plt.subplots(nrows=2, ncols=n, figsize=(20,4))
for i in range(n):
    # display original
    ax = axes[0,i]
    ax.imshow(x_test[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = axes[1,i]
    ax.imshow(decoded_imgs[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
STD = .3

# %%
input_img = keras.layers.Input(
    shape=(28, 28,
           1))  # adapt this if using `channels_first` image data format

x = keras.layers.GaussianNoise(STD)(input_img)

x = keras.layers.Conv2D(
    16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(32, (3, 3), activation='elu', padding='same')(x)
encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (1, 1, 32) i.e. 128-dimensional

x = keras.layers.Conv2DTranspose(
    32, (3, 3), strides=(2, 2), activation="elu", padding='valid')(encoded)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='valid')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

decoded = keras.layers.Conv2D(
    1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.models.Model(input_img, decoded)

autoencoder.summary()

autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# gaussian_noise_4 (GaussianNo (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 14, 14, 16)        2320
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 7, 7, 16)          2320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 4, 4, 16)          2320
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 2, 2, 16)          0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 2, 2, 32)          4640
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 1, 1, 32)          0
# _________________________________________________________________
# conv2d_transpose_21 (Conv2DT (None, 3, 3, 32)          9248
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 3, 3, 16)          4624
# _________________________________________________________________
# conv2d_transpose_22 (Conv2DT (None, 7, 7, 16)          2320
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 7, 7, 16)          2320
# _________________________________________________________________
# conv2d_transpose_23 (Conv2DT (None, 14, 14, 16)        2320
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 14, 14, 16)        2320
# _________________________________________________________________
# conv2d_transpose_24 (Conv2DT (None, 28, 28, 16)        2320
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 39,697
# Trainable params: 39,697
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_test_noise = x_test + np.random.normal(scale=STD, size=x_test.shape)

# %%
autoencoder.fit(x_train, x_train, batch_size=256,
                epochs=100,
                shuffle=True,
                validation_data=(x_test_noise, x_test),
                callbacks=callbacks
               )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 7s 117us/step - loss: 0.2377 - val_loss: 0.1751
# Epoch 2/100
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.1597 - val_loss: 0.1469
# Epoch 3/100
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.1398 - val_loss: 0.1400
# Epoch 4/100
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1294 - val_loss: 0.1223
# Epoch 5/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1225 - val_loss: 0.1223
# Epoch 6/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1176 - val_loss: 0.1140
# Epoch 7/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1142 - val_loss: 0.1148
# Epoch 8/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1112 - val_loss: 0.1118
# Epoch 9/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1088 - val_loss: 0.1099
# Epoch 10/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1071 - val_loss: 0.1059
# Epoch 11/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1052 - val_loss: 0.1069
# Epoch 12/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1039 - val_loss: 0.1031
# Epoch 13/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1026 - val_loss: 0.1010
# Epoch 14/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1015 - val_loss: 0.1030
# Epoch 15/100
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1003 - val_loss: 0.1013
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 16/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0954 - val_loss: 0.0945
# Epoch 17/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0949 - val_loss: 0.0941
# Epoch 18/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0949 - val_loss: 0.0946
# Epoch 19/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0946 - val_loss: 0.0958
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0930 - val_loss: 0.0922
# Epoch 21/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0927 - val_loss: 0.0920
# Epoch 22/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0925 - val_loss: 0.0919
# Epoch 23/100
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0922 - val_loss: 0.0918
# Epoch 24/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0921 - val_loss: 0.0917
# Epoch 25/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0919 - val_loss: 0.0911
# Epoch 26/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0916 - val_loss: 0.0907
# Epoch 27/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0914 - val_loss: 0.0909
# Epoch 28/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0912 - val_loss: 0.0906
# Epoch 29/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0909 - val_loss: 0.0911
# Epoch 30/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0907 - val_loss: 0.0901
# Epoch 31/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0905 - val_loss: 0.0896
# Epoch 32/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0904 - val_loss: 0.0900
# Epoch 33/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0901 - val_loss: 0.0898
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 34/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0895 - val_loss: 0.0889
# Epoch 35/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0895 - val_loss: 0.0889
# Epoch 36/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0894 - val_loss: 0.0888
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 37/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0892 - val_loss: 0.0885
# Epoch 38/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0891 - val_loss: 0.0885
# Epoch 39/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0890 - val_loss: 0.0884
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 40/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0890 - val_loss: 0.0883
# Epoch 41/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0889 - val_loss: 0.0883
# Epoch 42/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0889 - val_loss: 0.0883
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 43/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0889 - val_loss: 0.0882
# Epoch 44/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0888 - val_loss: 0.0882
# Epoch 45/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0888 - val_loss: 0.0882
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 46/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0888 - val_loss: 0.0882
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 47/100
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0888 - val_loss: 0.0881
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 48/100
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0887 - val_loss: 0.0881
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 00048: early stopping

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

fig, axes = plt.subplots(nrows=3, ncols=n, figsize=(20,6))
for i in range(n):
    # display input
    ax = axes[0,i]
    ax.imshow(x_test_noise[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = axes[1,i]
    ax.imshow(decoded_imgs[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display original
    ax = axes[2,i]
    ax.imshow(x_test[i].reshape(28, 28), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
(x_train, _), (x_test, _) = keras.datasets.cifar100.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
np.std(x_train, axis=(1,2,3)).mean()
# Out:
# 0.21646152

# %%
STD = .1

x_test_noise = x_test + np.random.normal(scale=STD, size=x_test.shape)

# %%
input_img = keras.layers.Input(
    shape=(32, 32,
           3))  # adapt this if using `channels_first` image data format

x = keras.layers.GaussianNoise(STD)(input_img)

x = keras.layers.Conv2D(
    16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = keras.layers.BatchNormalization()(x)

x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(32, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(64, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = keras.layers.Conv2D(128, (3, 3), activation='elu', padding='same')(x)
encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (1, 1, 32) i.e. 128-dimensional

x = keras.layers.Conv2DTranspose(
    128, (3, 3), strides=(2, 2), activation="elu", padding='same')(encoded)
x = keras.layers.Conv2D(128, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    64, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(64, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    32, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(32, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.Conv2DTranspose(
    16, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
x = keras.layers.Conv2D(16, (3, 3), activation='elu', padding='same')(x)

x = keras.layers.BatchNormalization()(x)

decoded = keras.layers.Conv2D(
    3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.models.Model(input_img, decoded)

autoencoder.summary()

autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train, batch_size=256,
                epochs=10,
                shuffle=True,
                validation_data=(x_test_noise, x_test),
                callbacks=callbacks
               )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 32, 32, 3)         0
# _________________________________________________________________
# gaussian_noise_12 (GaussianN (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_133 (Conv2D)          (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 16)        64
# _________________________________________________________________
# conv2d_134 (Conv2D)          (None, 16, 16, 16)        2320
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_135 (Conv2D)          (None, 8, 8, 32)          4640
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 4, 4, 64)          18496
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 2, 2, 128)         73856
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 1, 1, 128)         0
# _________________________________________________________________
# conv2d_transpose_59 (Conv2DT (None, 2, 2, 128)         147584
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 2, 2, 128)         147584
# _________________________________________________________________
# conv2d_transpose_60 (Conv2DT (None, 4, 4, 64)          73792
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 4, 4, 64)          36928
# _________________________________________________________________
# conv2d_transpose_61 (Conv2DT (None, 8, 8, 32)          18464
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 8, 8, 32)          9248
# _________________________________________________________________
# conv2d_transpose_62 (Conv2DT (None, 16, 16, 16)        4624
# _________________________________________________________________
# conv2d_141 (Conv2D)          (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv2d_transpose_63 (Conv2DT (None, 32, 32, 16)        2320
# _________________________________________________________________
# conv2d_142 (Conv2D)          (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_143 (Conv2D)          (None, 32, 32, 3)         435
# =================================================================
# Total params: 545,507
# Trainable params: 545,443
# Non-trainable params: 64
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 10s 203us/step - loss: 0.6167 - val_loss: 0.6072
# Epoch 2/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.6021 - val_loss: 0.5900
# Epoch 3/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5849 - val_loss: 0.5888
# Epoch 4/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5755 - val_loss: 0.5738
# Epoch 5/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5713 - val_loss: 0.5735
# Epoch 6/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5687 - val_loss: 0.5762
# Epoch 7/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5663 - val_loss: 0.5671
# Epoch 8/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5647 - val_loss: 0.5646
# Epoch 9/10
# 50000/50000 [==============================] - 8s 162us/step - loss: 0.5633 - val_loss: 0.5623
# Epoch 10/10
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.5621 - val_loss: 0.5629

# %%
import keras.backend as K

# %%
input_img = keras.layers.Input(
    shape=(32, 32,
           3))  # adapt this if using `channels_first` image data format

x = keras.layers.GaussianNoise(STD)(input_img)

enc_32 = keras.layers.Conv2D(
    64, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(enc_32)
x = keras.layers.BatchNormalization()(x)

enc_16 = keras.layers.Conv2D(64, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(enc_16)

enc_8 = keras.layers.Conv2D(64, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(enc_8)

enc_4 = keras.layers.Conv2D(64, (3, 3), activation='elu', padding='same')(x)
x = keras.layers.MaxPooling2D((2, 2), padding='same')(enc_4)

enc_2 = keras.layers.Conv2D(256, (3, 3), activation='elu', padding='same')(x)
# encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (1, 1, 32) i.e. 128-dimensional

# x = keras.layers.Conv2DTranspose(
#     128, (3, 3), strides=(2, 2), activation="elu", padding='same')(encoded)
# x = keras.layers.SeparableConv2D(128, (3, 3), activation='elu', padding='same')(x)

dec_4 = keras.layers.Conv2DTranspose(
    64, (3, 3), strides=(2, 2), activation="elu", padding='same')(enc_2)
comb_4 = keras.layers.Concatenate(axis=3)( [dec_4,enc_4] )
x = keras.layers.Conv2D(128, (3, 3), activation='elu', padding='same')(comb_4)

dec_8 = keras.layers.Conv2DTranspose(
    64, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
comb_8 = keras.layers.Concatenate(axis=3)( [dec_8,enc_8] )
x = keras.layers.Conv2D(128, (3, 3), activation='elu', padding='same')(comb_8)

enc_16 = keras.layers.Conv2DTranspose(
    64, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
comb_16 = keras.layers.Concatenate(axis=3)( [dec_16,enc_16] )
x = keras.layers.Conv2D(128, (3, 3), activation='elu', padding='same')(comb_16)

enc_32 = keras.layers.Conv2DTranspose(
    64, (3, 3), strides=(2, 2), activation="elu", padding='same')(x)
comb_32 = keras.layers.Concatenate(axis=3)( [dec_32,enc_32] )
x = keras.layers.Conv2D(64, (3, 3), activation='elu', padding='same')(comb_32)

x = keras.layers.BatchNormalization()(x)

decoded = keras.layers.Conv2D(
    3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.models.Model(input_img, decoded)

autoencoder.summary(line_length=100)

autoencoder.compile(optimizer='nadam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train, batch_size=256,
                epochs=100,
                shuffle=True,
                validation_data=(x_test_noise, x_test),
                callbacks=callbacks
               )
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_33 (InputLayer)            (None, 32, 32, 3)     0
# ____________________________________________________________________________________________________
# gaussian_noise_28 (GaussianNoise (None, 32, 32, 3)     0           input_33[0][0]
# ____________________________________________________________________________________________________
# conv2d_229 (Conv2D)              (None, 32, 32, 64)    1792        gaussian_noise_28[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_133 (MaxPooling2D) (None, 16, 16, 64)    0           conv2d_229[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_30 (BatchNor (None, 16, 16, 64)    256         max_pooling2d_133[0][0]
# ____________________________________________________________________________________________________
# conv2d_230 (Conv2D)              (None, 16, 16, 64)    36928       batch_normalization_30[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_134 (MaxPooling2D) (None, 8, 8, 64)      0           conv2d_230[0][0]
# ____________________________________________________________________________________________________
# conv2d_231 (Conv2D)              (None, 8, 8, 64)      36928       max_pooling2d_134[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_135 (MaxPooling2D) (None, 4, 4, 64)      0           conv2d_231[0][0]
# ____________________________________________________________________________________________________
# conv2d_232 (Conv2D)              (None, 4, 4, 64)      36928       max_pooling2d_135[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_136 (MaxPooling2D) (None, 2, 2, 64)      0           conv2d_232[0][0]
# ____________________________________________________________________________________________________
# conv2d_233 (Conv2D)              (None, 2, 2, 256)     147712      max_pooling2d_136[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_111 (Conv2DTran (None, 4, 4, 64)      147520      conv2d_233[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 4, 4, 128)     0           conv2d_transpose_111[0][0]
#                                                                    conv2d_232[0][0]
# ____________________________________________________________________________________________________
# separable_conv2d_43 (SeparableCo (None, 4, 4, 256)     34176       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_112 (Conv2DTran (None, 8, 8, 128)     295040      separable_conv2d_43[0][0]
# ____________________________________________________________________________________________________
# separable_conv2d_44 (SeparableCo (None, 8, 8, 128)     17664       conv2d_transpose_112[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_113 (Conv2DTran (None, 16, 16, 64)    73792       separable_conv2d_44[0][0]
# ____________________________________________________________________________________________________
# separable_conv2d_45 (SeparableCo (None, 16, 16, 64)    4736        conv2d_transpose_113[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_114 (Conv2DTran (None, 32, 32, 64)    36928       separable_conv2d_45[0][0]
# ____________________________________________________________________________________________________
# separable_conv2d_46 (SeparableCo (None, 32, 32, 64)    4736        conv2d_transpose_114[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_31 (BatchNor (None, 32, 32, 64)    256         separable_conv2d_46[0][0]
# ____________________________________________________________________________________________________
# conv2d_234 (Conv2D)              (None, 32, 32, 3)     1731        batch_normalization_31[0][0]
# ====================================================================================================
# Total params: 877,123
# Trainable params: 876,867
# Non-trainable params: 256
# ____________________________________________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 20s 408us/step - loss: 0.5880 - val_loss: 0.5814
# Epoch 2/100
# 50000/50000 [==============================] - 16s 324us/step - loss: 0.5591 - val_loss: 0.5655
# Epoch 3/100
# 50000/50000 [==============================] - 16s 325us/step - loss: 0.5542 - val_loss: 0.5644
# Epoch 4/100
# 50000/50000 [==============================] - 16s 325us/step - loss: 0.5508 - val_loss: 0.5745
# Epoch 5/100
# 50000/50000 [==============================] - 16s 325us/step - loss: 0.5477 - val_loss: 0.5514
# Epoch 6/100
# 50000/50000 [==============================] - 16s 325us/step - loss: 0.5459 - val_loss: 0.5542
# Epoch 7/100
# 50000/50000 [==============================] - 16s 326us/step - loss: 0.5446 - val_loss: 0.5457
# Epoch 8/100
# 50000/50000 [==============================] - 16s 325us/step - loss: 0.5434 - val_loss: 0.5485
# Epoch 9/100
# 50000/50000 [==============================] - 16s 324us/step - loss: 0.5428 - val_loss: 0.5435
# Epoch 10/100
# 50000/50000 [==============================] - 16s 326us/step - loss: 0.5419 - val_loss: 0.5450
# Epoch 11/100
# 24064/50000 [=============>................] - ETA: 7s - loss: 0.5417

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

fig, axes = plt.subplots(nrows=3, ncols=n, figsize=(20,6))
for i in range(n):
    # display input
    ax = axes[0,i]
    ax.imshow(x_test_noise[i].reshape(32, 32,3), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = axes[1,i]
    ax.imshow(decoded_imgs[i].reshape(32, 32,3), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display original
    ax = axes[2,i]
    ax.imshow(x_test[i].reshape(32, 32,3), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
